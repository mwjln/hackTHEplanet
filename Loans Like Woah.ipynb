# %% [markdown]
# ## Loan Data Project

# %%
#Check and Change WD
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# print os.getcwd()

# %%
wd = 'Data/lending-club-loan-data/'
loans=pd.read_csv(wd+'loan.csv')
loans.head()
# Out:
# /Users/mwjln/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     10.65       162.87     B        B2     ...               NaN     NaN
# 1     15.27        59.83     C        C4     ...               NaN     NaN
# ...

# %%
loans.describe()
# Out:
# /Users/mwjln/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                  id     member_id      loan_amnt    funded_amnt  \
# count  8.873790e+05  8.873790e+05  887379.000000  887379.000000
# mean   3.246513e+07  3.500182e+07   14755.264605   14741.877625
# std    2.282734e+07  2.411335e+07    8435.455601    8429.897657
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    9.206643e+06  1.087713e+07    8000.000000    8000.000000
# 50%    3.443327e+07  3.709528e+07   13000.000000   13000.000000
# 75%    5.490814e+07  5.847135e+07   20000.000000   20000.000000
# max    6.861706e+07  7.354484e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    887379.000000  887379.000000  887379.000000  8.873750e+05
# mean      14702.464383      13.246740     436.717127  7.502759e+04
# ...

# %%
# for column in loans.columns:
#     print column

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
# id                             887379 non-null int64
# member_id                      887379 non-null int64
# loan_amnt                      887379 non-null float64
# funded_amnt                    887379 non-null float64
# funded_amnt_inv                887379 non-null float64
# term                           887379 non-null object
# int_rate                       887379 non-null float64
# installment                    887379 non-null float64
# grade                          887379 non-null object
# sub_grade                      887379 non-null object
# emp_title                      835922 non-null object
# emp_length                     887379 non-null object
# home_ownership                 887379 non-null object
# annual_inc                     887375 non-null float64
# verification_status            887379 non-null object
# ...

# %%
loans.loan_status.describe()
# Out:
# count      887379
# unique         10
# top       Current
# freq       601779
# Name: loan_status, dtype: object

# %%
loans.loan_status.unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', 'Issued'], dtype=object)

# %%
loans.addr_state.unique()
# Out:
# array(['AZ', 'GA', 'IL', 'CA', 'OR', 'NC', 'TX', 'VA', 'MO', 'CT', 'UT',
#        'FL', 'NY', 'PA', 'MN', 'NJ', 'KY', 'OH', 'SC', 'RI', 'LA', 'MA',
#        'WA', 'WI', 'AL', 'CO', 'KS', 'NV', 'AK', 'MD', 'WV', 'VT', 'MI',
#        'DC', 'SD', 'NH', 'AR', 'NM', 'MT', 'HI', 'WY', 'OK', 'DE', 'MS',
#        'TN', 'IA', 'NE', 'ID', 'IN', 'ME', 'ND'], dtype=object)

# %%
loans.groupby('addr_state').loan_status.value_counts()
# Out:
# addr_state  loan_status
# AK          Current                                                1469
#             Fully Paid                                              567
#             Charged Off                                              96
#             Late (31-120 days)                                       31
#             In Grace Period                                          15
#             Issued                                                   14
#             Late (16-30 days)                                         6
#             Does not meet the credit policy. Status:Fully Paid        4
#             Default                                                   2
#             Does not meet the credit policy. Status:Charged Off       1
# AL          Current                                                7576
#             Fully Paid                                             2485
#             Charged Off                                             662
# ...

# %%
loans.groupby(['addr_state','loan_status']).purpose.value_counts()
# Out:
# addr_state  loan_status                                          purpose
# AK          Charged Off                                          debt_consolidation     59
#                                                                  credit_card            21
#                                                                  home_improvement        5
#                                                                  other                   4
#                                                                  major_purchase          2
#                                                                  small_business          2
#                                                                  vacation                2
#                                                                  medical                 1
#             Current                                              debt_consolidation    902
# ...

# %%
loans.groupby(['addr_state', 'loan_status']).count()
# Out:
#                                                                  id  \
# addr_state loan_status
# AK         Charged Off                                           96
#            Current                                             1469
#            Default                                                2
#            Does not meet the credit policy. Status:Charged...     1
#            Does not meet the credit policy. Status:Fully Paid     4
#            Fully Paid                                           567
#            In Grace Period                                       15
#            Issued                                                14
#            Late (16-30 days)                                      6
#            Late (31-120 days)                                    31
# AL         Charged Off                                          662
#            Current                                             7576
# ...

# %% [markdown]
# ### What we'd like to do
# ##### Take a look at the ratios of fully paid to current VS charged off to current, by state, to get an idea of which states tend toward good or bad loans

# %%
grouped = loans.groupby(['addr_state','loan_status']).purpose.value_counts()

# %%
loans[(loans.annual_inc<50000)].groupby(['purpose']).loan_amnt.mean()
# Out:
# purpose
# car                    6757.362869
# credit_card            9932.443025
# debt_consolidation    10004.081048
# educational            5012.204724
# home_improvement       8812.065064
# house                  9362.561335
# major_purchase         7501.422610
# medical                6424.761824
# moving                 5401.182894
# other                  6702.098450
# renewable_energy       6569.756098
# small_business         9008.068182
# vacation               4926.234568
# wedding                7473.288973
# Name: loan_amnt, dtype: float64

# %%
graph = loans[(loans.annual_inc<50000)].groupby(['purpose']).loan_amnt.mean()

# %%
plt.graph.plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-a26f9c82aab2> in <module>()
# ----> 1 plt.graph.plot(kind='bar')
#       2 plt.show()
#
# AttributeError: 'module' object has no attribute 'graph'
